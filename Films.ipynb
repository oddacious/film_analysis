# %%
#!/usr/bin/python

import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

import sqlite3

from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import chi2_kernel

import db_wrapper

def build_dataset(db):
    films = db.get_cursor().execute("SELECT DISTINCT(film_link) FROM films").fetchall()
    lists = db.get_cursor().execute("SELECT DISTINCT(list_link) FROM lists").fetchall()

    lists_flat = [item[0] for item in lists]
    films_flat = [item[0] for item in films]

    zeroes = np.zeros(shape=(len(films_flat), len(lists_flat)))
    df = pd.DataFrame(zeroes, index=films_flat, columns=lists_flat)

#    print df.index
#    print df.index[1]
#    print df.ix['/movies/12+angry+men/']

    for item in db.get_cursor().execute("SELECT * FROM list_items").fetchall():
        df[item[1]][item[2]] = 1

    return df

db = db_wrapper.db_wrapper(name="icheckmovies.db")
df = build_dataset(db)

# %%
count = 0
connections = {}

for i in range(0, len(df)):
    connections[df.index[i]] = {}
    for j in range(0, len(df)):
        if j >= i:
            continue
        count = count + 1
        #connections[df.index[i]][j] = 0
        #for i in range(0, len(df.columns)):
            
print count
# Out:
# 100231561

# %%
count = 0
connections = {}

for i in range(0, len(df.columns)):
    connections[df.columns[i]] = {}
    for j in range(i + 1, len(df.columns)):
        for k in range(0, len(df)):
            if df.iloc[k][i] == 1 and df.iloc[k][j] == 1:
                count = count + 1
        #connections[df.index[i]][j] = 0
        #for i in range(0, len(df.columns)):
            
print count

# %%
X = StandardScaler().fit_transform(df)

# %%
X.shape
# Out:
# (14159L, 174L)

# %%
db = DBSCAN(eps=0.3, min_samples=10).fit(X)

# %%
import matplotlib.pyplot as plt

core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()

# %%
from sklearn.cluster import KMeans

plt.figure(figsize=(12, 12))

random_state = 1700

clusterer = KMeans(n_clusters=10, random_state=random_state)
y_pred = clusterer.fit_predict(X)
y_pred

unique, counts = np.unique(y_pred, return_counts=True)

print np.asarray((unique, counts)).T
# Out:
# [[    0   113]
#  [    1   744]
#  [    2   748]
#  [    3   116]
#  [    4 11129]
#  [    5   305]
#  [    6    33]
#  [    7   460]
#  [    8    83]
#  [    9   428]]

# %%
import numpy.linalg
np.linalg.matrix_rank(df.T)
len(df.drop_duplicates())
# Out:
# 4144

# %%
popular = df[df.sum(axis=1) > 10]
print len(popular)
print np.linalg.matrix_rank(popular) # 157 of the 174 lists are represented

K2 = chi2_kernel(popular)

best = 0
best_i = 0
best_j = 0
exact = 0
for i in range(len(K2)):
    for j in range(i + 1, len(K2)):
        if K2[i][j] == 1:
            exact = exact + 1
        if K2[i][j] > best:
            best = K2[i][j]
            best_i = i
            best_j = j
# Out:
# 586
# 157

# %%
print best_i
print best_j
print exact
print np.amax(K2)
print np.amin(K2)
# Out:
# 483
# 0
# 1
# 1.0
# 5.24288566336e-22

# %%
popular.index[317]
# Out:
# u'/movies/olympia+2.+teil+-+fest+der+schonheit/'

# %%
#item = popular.index.tolist().index(u'/movies/alien/')
item = popular.index.tolist().index(u'/movies/fight+club/')
item = popular.index.tolist().index(u'/movies/the+green+mile/')

print item

best = 0
best_i = 0
best_j = 0
print len(K2[item])
for i in range(len(K2[item])):
    if i == item:
        continue
    if K2[item][i] > best:
        best = K2[item][i]
        best_i = i

print best, best_i, popular.index[best_i], popular.index[item]
# Out:
# 460
# 586
# 0.00247875217667 34 /movies/american+history+x/ /movies/the+green+mile/

# %%
from sklearn.cluster import KMeans

plt.figure(figsize=(12, 12))

random_state = 1700

X = StandardScaler().fit_transform(popular)

clusterer = KMeans(n_clusters=10, random_state=random_state)
y_pred = clusterer.fit_predict(X)
#print y_pred

unique, counts = np.unique(y_pred, return_counts=True)

groups = {}
for item in unique:
    groups[item] = popular.index[y_pred == item]
    
print groups
print np.asarray((unique, counts)).T
# Out:
# {0: Index([                                                                          u'/movies/a+hard+days+night/',
#                                                                         u'/movies/a+matter+of+life+and+death/',
#                                                                                    u'/movies/black+narcissus/',
#                                                                                             u'/movies/blowup/',
#                                                                                             u'/movies/brazil/',
#                                                                                    u'/movies/brief+encounter/',
#                                                                                      u'/movies/dont+look+now/',
#                                                                                 u'/movies/great+expectations/',
#                                                                                             u'/movies/if..../',
#                                                                           u'/movies/kind+hearts+and+coronets/',
#                                                                                      u'/movies/life+of+brian/',
#                                                                                        u'/movies/peeping+tom/',
#                                                                                        u'/movies/performance/',
#                                                                                   u'/movies/secrets+and+lies/',
#                                                                                       u'/movies/the+39+steps/',
#        u'/movies/the+chronicle+history+of+king+henry+the+fift+with+his+battell+fought+at+agincourt+in+france/',
#                                                                                  u'/movies/the+lady+vanishes/',
#                                                                u'/movies/the+life+and+death+of+colonel+blimp/',
#                                                                                          u'/movies/the+piano/',
#                                                                                      u'/movies/the+red+shoes/',
#                                                                                        u'/movies/the+servant/',
#                                                                                      u'/movies/trainspotting/',
#                                                                                          u'/movies/viridiana/',
#                                                                                          u'/movies/walkabout/',
#                                                                                     u'/movies/withnail+and+i/'],
#       dtype='object'), 1: Index([                            u'/movies/a+clockwork+orange/',
#                                                 u'/movies/alien/',
#                                                u'/movies/aliens/',
#                                           u'/movies/blue+velvet/',
#                                 u'/movies/bride+of+frankenstein/',
#                                            u'/movies/cat+people/',
#                          u'/movies/das+testament+des+dr.+mabuse/',
#                                      u'/movies/dawn+of+the+dead/',
#                                         u'/movies/dead+of+night/',
#                                          u'/movies/dead+ringers/',
#                                          u'/movies/delicatessen/',
#                                           u'/movies/deliverance/',
#                                               u'/movies/dracula/',
#                                            u'/movies/eraserhead/',
#                                          u'/movies/frankenstein/',
#                                                u'/movies/freaks/',
#                                               u'/movies/gwoemul/',
#                                             u'/movies/halloween/',
#                        u'/movies/invasion+of+the+body+snatchers/',
#                                                u'/movies/kaidan/',
#                      u'/movies/lagaan+once+upon+a+time+in+india/',
#                                u'/movies/lat+den+ratte+komma+in/',
#                                       u'/movies/les+diaboliques/',
#                                  u'/movies/les+yeux+sans+visage/',
#                                               u'/movies/mad+max/',
#                                        u'/movies/mulholland+dr./',
#                                         u'/movies/neco+z+alenky/',
#                              u'/movies/night+of+the+living+dead/',
#                                               u'/movies/odishon/',
#                                              u'/movies/oldeuboi/',
#                                               u'/movies/onibaba/',
#                                u'/movies/picnic+at+hanging+rock/',
#                                    u'/movies/planet+of+the+apes/',
#                                                u'/movies/psycho/',
#                                             u'/movies/repulsion/',
#                                        u'/movies/rosemarys+baby/',
#                                        u'/movies/salinui+chueok/',
#                                     u'/movies/shaun+of+the+dead/',
#                                              u'/movies/suspiria/',
#                                             u'/movies/the+birds/',
#                               u'/movies/the+blair+witch+project/',
#                                          u'/movies/the+exorcist/',
#                                           u'/movies/the+shining/',
#                          u'/movies/the+texas+chain+saw+massacre/',
#                                             u'/movies/the+thing/',
#                                        u'/movies/the+wicker+man/',
#                                                u'/movies/vampyr/',
#                                            u'/movies/videodrome/',
#        u'/movies/what+ever+happened+to+baby+janequestion-1962-1/',
#                                    u'/movies/young+frankenstein/'],
#       dtype='object'), 2: Index([                          u'/movies/42nd+street/',
#                        u'/movies/a+man+for+all+seasons/',
#                         u'/movies/a+night+at+the+opera/',
#                           u'/movies/a+place+in+the+sun/',
#                               u'/movies/a+star+is+born/',
#                     u'/movies/a+streetcar+named+desire/',
#                          u'/movies/airplaneexclamation/',
#                                u'/movies/all+about+eve/',
#               u'/movies/all+quiet+on+the+western+front/',
#                                u'/movies/all+that+jazz/',
#        ...
#                         u'/movies/to+have+and+have+not/',
#                        u'/movies/to+kill+a+mockingbird/',
#                                      u'/movies/tootsie/',
#                                      u'/movies/top+hat/',
#                          u'/movies/trouble+in+paradise/',
#                                   u'/movies/unforgiven/',
#                                      u'/movies/vertigo/',
#                              u'/movies/west+side+story/',
#        u'/movies/whos+afraid+of+virginia+woolfquestion/',
#                          u'/movies/yankee+doodle+dandy/'],
#       dtype='object', length=146), 3: Index([                               u'/movies/a+bout+de+souffle/',
#                             u'/movies/a+woman+under+the+influence/',
#                                 u'/movies/aguirre+der+zorn+gottes/',
#                                            u'/movies/ai+no+korida/',
#                                       u'/movies/aleksandr+nevskiy/',
#        u'/movies/alphaville+une+etrange+aventure+de+lemmy+caution/',
#                                          u'/movies/andrey+rublyov/',
#                                   u'/movies/angst+essen+seele+auf/',
#                                               u'/movies/aparajito/',
#                                             u'/movies/apur+sansar/',
#        ...
#                                                u'/movies/week+end/',
#                                  u'/movies/werckmeister+harmoniak/',
#                                         u'/movies/wo+hu+cang+long/',
#                                                  u'/movies/xia+nu/',
#                                       u'/movies/y+tu+mama+tambien/',
#                                                   u'/movies/yi+yi/',
#                                                 u'/movies/yojinbo/',
#                                                       u'/movies/z/',
#                                                 u'/movies/zerkalo/',
#              u'/movies/zero+de+conduite+jeunes+diables+au+college/'],
#       dtype='object', length=155), 4: Index([        u'/movies/ace+in+the+hole/',
#           u'/movies/deadly+is+the+female/',
#               u'/movies/double+indemnity/',
#              u'/movies/in+a+lonely+place/',
#                 u'/movies/kiss+me+deadly/',
#                          u'/movies/laura/',
#                 u'/movies/mildred+pierce/',
#                      u'/movies/notorious/',
#                u'/movies/out+of+the+past/',
#         u'/movies/pickup+on+south+street/',
#                u'/movies/scarface-1932-1/',
#              u'/movies/shadow+of+a+doubt/',
#           u'/movies/strangers+on+a+train/',
#                   u'/movies/sunset+blvd./',
#         u'/movies/sweet+smell+of+success/',
#             u'/movies/the+asphalt+jungle/',
#                   u'/movies/the+big+heat/',
#                  u'/movies/the+big+sleep/',
#                    u'/movies/the+killers/',
#                    u'/movies/the+killing/',
#               u'/movies/the+lost+weekend/',
#             u'/movies/the+maltese+falcon/',
#        u'/movies/the+night+of+the+hunter/',
#                  u'/movies/the+third+man/',
#                  u'/movies/touch+of+evil/',
#                     u'/movies/white+heat/'],
#       dtype='object'), 5: Index([                                         u'/movies/12+angry+men/',
#                                             u'/movies/12+years+a+slave/',
#                                         u'/movies/2001+a+space+odyssey/',
#                                             u'/movies/a+beautiful+mind/',
#                                                      u'/movies/amadeus/',
#                                              u'/movies/american+beauty/',
#                                           u'/movies/american+history+x/',
#                                                u'/movies/amores+perros/',
#                                               u'/movies/apocalypse+now/',
#                                                       u'/movies/avatar/',
#                                           u'/movies/back+to+the+future/',
#                                                u'/movies/batman+begins/',
#                                                u'/movies/before+sunset/',
#                                                   u'/movies/black+swan/',
#                                                 u'/movies/blade+runner/',
#                                                   u'/movies/braveheart/',
#                                                       u'/movies/casino/',
#                                       u'/movies/cera+una+volta+il+west/',
#                                               u'/movies/cidade+de+deus/',
#                                                     u'/movies/das+boot/',
#                                        u'/movies/das+leben+der+anderen/',
#                                                u'/movies/der+untergang/',
#                                                     u'/movies/die+hard/',
#                                                   u'/movies/district+9/',
#                                             u'/movies/django+unchained/',
#                                                 u'/movies/donnie+darko/',
#                                       u'/movies/el+laberinto+del+fauno/',
#                        u'/movies/eternal+sunshine+of+the+spotless+mind/',
#                                                        u'/movies/fargo/',
#                                                   u'/movies/fight+club/',
#                                                 u'/movies/forrest+gump/',
#                                            u'/movies/full+metal+jacket/',
#                                                    u'/movies/gladiator/',
#                                                   u'/movies/goodfellas/',
#                                                         u'/movies/heat/',
#                               u'/movies/il+buono+il+brutto+il+cattivo./',
#                                                    u'/movies/inception/',
#                           u'/movies/indiana+jones+and+the+last+crusade/',
#                                         u'/movies/inglourious+basterds/',
#                                                         u'/movies/jaws/',
#                                                u'/movies/jurassic+park/',
#                                             u'/movies/kill+bill+vol.+1/',
#                                            u'/movies/l.a.+confidential/',
#                                              u'/movies/la+vita+e+bella/',
#                           u'/movies/le+fabuleux+destin+damelie+poulain/',
#                                                         u'/movies/leon/',
#                                          u'/movies/lost+in+translation/',
#                                                     u'/movies/magnolia/',
#                                                      u'/movies/memento/',
#                              u'/movies/monty+python+and+the+holy+grail/',
#                                       u'/movies/no+country+for+old+men/',
#                                           u'/movies/north+by+northwest/',
#                                  u'/movies/once+upon+a+time+in+america/',
#                               u'/movies/one+flew+over+the+cuckoos+nest/',
#        u'/movies/pirates+of+the+caribbean+the+curse+of+the+black+pearl/',
#                                                      u'/movies/platoon/',
#                                                 u'/movies/pulp+fiction/',
#                                      u'/movies/raiders+of+the+lost+ark/',
#                                                     u'/movies/rain+man/',
#                                          u'/movies/requiem+for+a+dream/',
#                                               u'/movies/reservoir+dogs/',
#                                          u'/movies/saving+private+ryan/',
#                                                     u'/movies/scarface/',
#                                              u'/movies/schindlers+list/',
#                                                        u'/movies/se7en/',
#                                          u'/movies/slumdog+millionaire/',
#                u'/movies/star+wars+episode+v+-+the+empire+strikes+back/',
#                    u'/movies/star+wars+episode+vi+-+return+of+the+jedi/',
#                                                    u'/movies/star+wars/',
#                                                  u'/movies/taxi+driver/',
#                                    u'/movies/terminator+2+judgment+day/',
#                                             u'/movies/the+big+lebowski/',
#                                              u'/movies/the+dark+knight/',
#                                                 u'/movies/the+departed/',
#                                        u'/movies/the+godfather+part+ii/',
#                                                u'/movies/the+godfather/',
#                                               u'/movies/the+green+mile/',
#                                             u'/movies/the+kings+speech/',
#             u'/movies/the+lord+of+the+rings+the+fellowship+of+the+ring/',
#                 u'/movies/the+lord+of+the+rings+the+return+of+the+king/',
#                         u'/movies/the+lord+of+the+rings+the+two+towers/',
#                                                   u'/movies/the+matrix/',
#                                                  u'/movies/the+pianist/',
#                                                 u'/movies/the+prestige/',
#                                           u'/movies/the+princess+bride/',
#                                     u'/movies/the+shawshank+redemption/',
#                                     u'/movies/the+silence+of+the+lambs/',
#                                              u'/movies/the+sixth+sense/',
#                                               u'/movies/the+terminator/',
#                                           u'/movies/the+usual+suspects/',
#                               u'/movies/the+wolf+of+wall+street-2013-1/',
#                                          u'/movies/there+will+be+blood/',
#                                                      u'/movies/titanic/',
#                                               u'/movies/twelve+monkeys/',
#                                              u'/movies/whiplash-2014-1/'],
#       dtype='object'), 6: Index([                      u'/movies/8/',
#                       u'/movies/amarcord/',
#                 u'/movies/il+conformista/',
#                  u'/movies/il+gattopardo/',
#         u'/movies/la+battaglia+di+algeri/',
#                  u'/movies/la+dolce+vita/',
#                      u'/movies/la+strada/',
#            u'/movies/ladri+di+biciclette/',
#            u'/movies/le+notti+di+cabiria/',
#                       u'/movies/leclisse/',
#          u'/movies/nuovo+cinema+paradiso/',
#                     u'/movies/ossessione/',
#                          u'/movies/paisa/',
#        u'/movies/rocco+e+i+suoi+fratelli/',
#              u'/movies/roma+citta+aperta/',
#                          u'/movies/senso/',
#                     u'/movies/umberto+d./'],
#       dtype='object'), 7: Index([                          u'/movies/akira/',
#                                u'/movies/aladdin/',
#                                  u'/movies/bambi/',
#                   u'/movies/beauty+and+the+beast/',
#                               u'/movies/fantasia/',
#                           u'/movies/finding+nemo/',
#                   u'/movies/hauru+no+ugoku+shiro/',
#                         u'/movies/hotaru+no+haka/',
#                         u'/movies/kokaku+kidotai/',
#                          u'/movies/mononoke-hime/',
#                          u'/movies/monsters+inc./',
#                              u'/movies/pinocchio/',
#          u'/movies/sen+to+chihiro+no+kamikakushi/',
#                                  u'/movies/shrek/',
#        u'/movies/snow+white+and+the+seven+dwarfs/',
#                          u'/movies/the+lion+king/',
#         u'/movies/the+nightmare+before+christmas/',
#                       u'/movies/tonari+no+totoro/',
#                            u'/movies/toy+story+2/',
#                            u'/movies/toy+story+3/',
#                              u'/movies/toy+story/',
#                                     u'/movies/up/',
#                                  u'/movies/walle/',
#                u'/movies/who+framed+roger+rabbit/'],
#       dtype='object'), 8: Index([u'/movies/chelovek+s+kino-apparatom/',
#                      u'/movies/hoop+dreams/',
#                    u'/movies/koyaanisqatsi/',
#              u'/movies/nanook+of+the+north/',
#               u'/movies/nuit+et+brouillard/',
#                      u'/movies/sans+soleil/',
#                            u'/movies/shoah/',
#              u'/movies/triumph+des+willens/'],
#       dtype='object'), 9: Index([u'/movies/broken+blossoms+or+the+yellow+man+and+the+girl/',
#                                  u'/movies/bronenosets+potemkin/',
#                                           u'/movies/city+lights/',
#                         u'/movies/das+cabinet+des+dr.+caligari./',
#                                       u'/movies/der+letzte+mann/',
#                                u'/movies/die+buchse+der+pandora/',
#            u'/movies/dr.+mabuse+der+spieler+-+ein+bild+der+zeit/',
#                       u'/movies/faust+-+eine+deutsche+volkssage/',
#                                                 u'/movies/greed/',
#                                                 u'/movies/haxan/',
#        u'/movies/intolerance+loves+struggle+throughout+the+ages/',
#                                             u'/movies/korkarlen/',
#                             u'/movies/la+passion+de+jeanne+darc/',
#                                u'/movies/le+voyage+dans+la+lune/',
#                                          u'/movies/les+vampires/',
#                                            u'/movies/metropolis/',
#                                              u'/movies/napoleon/',
#                  u'/movies/nosferatu+eine+symphonie+des+grauens/',
#                                               u'/movies/oktyabr/',
#           u'/movies/otona+no+miru+ehon+-+umarete+wa+mita+keredo/',
#                                       u'/movies/our+hospitality/',
#                                u'/movies/safety+lastexclamation/',
#                                          u'/movies/sherlock+jr./',
#                                               u'/movies/stachka/',
#                                    u'/movies/steamboat+bill+jr./',
#                          u'/movies/sunrise+a+song+of+two+humans/',
#                                        u'/movies/the+big+parade/',
#                                 u'/movies/the+birth+of+a+nation/',
#                                         u'/movies/the+cameraman/',
#                                             u'/movies/the+crowd/',
#                                           u'/movies/the+general/',
#                                         u'/movies/the+gold+rush/',
#                               u'/movies/the+great+train+robbery/',
#                                               u'/movies/the+kid/',
#                                         u'/movies/the+navigator/',
#                              u'/movies/the+phantom+of+the+opera/',
#                            u'/movies/the+thief+of+bagdad-1924-1/',
#                                              u'/movies/the+wind/',
#                                      u'/movies/un+chien+andalou/',
#                                                u'/movies/zemlya/'],
#       dtype='object')}
# [[  0  25]
#  [  1  50]
#  [  2 146]
#  [  3 155]
#  [  4  26]
#  [  5  95]
#  [  6  17]
#  [  7  24]
#  [  8   8]
#  [  9  40]]

# %%
from sklearn.cluster import KMeans

plt.figure(figsize=(12, 12))

random_state = 1700

X2 = StandardScaler().fit_transform(df.T)

clusterer = KMeans(n_clusters=10, random_state=random_state)
y_pred = clusterer.fit_predict(X2)
y_pred

unique, counts = np.unique(y_pred, return_counts=True)

print np.asarray((unique, counts)).T

db = DBSCAN(eps=0.3, min_samples=10).fit(X2)
labels = db.labels_
labels.shape
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_clusters_
print('Estimated number of clusters: %d' % n_clusters_)
# Out:
# [[  0   2]
#  [  1   1]
#  [  2   1]
#  [  3   1]
#  [  4 164]
#  [  5   1]
#  [  6   1]
#  [  7   1]
#  [  8   1]
#  [  9   1]]
# Estimated number of clusters: 0

# %%
by_list = df.T

counts = np.empty([len(by_list), len(by_list)])

results = pd.DataFrame(columns=['list 1', 'list 2', 'phi', 'abs_phi'])

import scipy

for i in range(0, len(by_list)):
    for j in range(i + 1, len(by_list)):
        corr = scipy.stats.stats.pearsonr(by_list.iloc[i], by_list.iloc[j])[0]
        results.loc[len(results) + 1] = [by_list.index[i], by_list.index[j], corr, abs(corr)]

# %%
results.sort(['phi'], ascending=1)[:20]
# Out:
#                                                  list 1  \
# 10568                        /lists/doubling+the+canon/
# 14669    /lists/the+21st+centurys+most+acclaimed+films/
# 7081              /lists/all-time+worldwide+box+office/
# 13748                    /lists/national+film+registry/
# 14911      /lists/they+shoot+zombies+dont+theyquestion/
# 7397       /lists/amos+vogels+film+as+a+subversive+art/
# 13370                     /lists/more+noirs+from+tspdt/
# 7979                 /lists/asian+cinema+a+field+guide/
# 7113              /lists/all-time+worldwide+box+office/
# 7972                 /lists/asian+cinema+a+field+guide/
# 7763   /lists/anthology+film+archives+essential+cinema/
# 13394                     /lists/more+noirs+from+tspdt/
# 7172              /lists/all-time+worldwide+box+office/
# 7152              /lists/all-time+worldwide+box+office/
# 10548                        /lists/doubling+the+canon/
# 7672   /lists/anthology+film+archives+essential+cinema/
# 7052              /lists/all-time+worldwide+box+office/
# 14648    /lists/the+21st+centurys+most+acclaimed+films/
# 7733   /lists/anthology+film+archives+essential+cinema/
# 7765   /lists/anthology+film+archives+essential+cinema/
#
#                                                   list 2       phi   abs_phi
# 10568              /lists/they+shoot+pictures+dont+they/ -0.086335  0.086335
# 14669  /lists/unescos+memory+of+the+world+national+ci... -0.068828  0.068828
# 7081                          /lists/doubling+the+canon/ -0.065431  0.065431
# 13748     /lists/the+21st+centurys+most+acclaimed+films/ -0.060458  0.060458
# 14911  /lists/unescos+memory+of+the+world+national+ci... -0.058229  0.058229
# 7397      /lists/the+21st+centurys+most+acclaimed+films/ -0.057819  0.057819
# 13370     /lists/the+21st+centurys+most+acclaimed+films/ -0.057163  0.057163
# 7979                      /lists/national+film+registry/ -0.056092  0.056092
# 7113         /lists/jonathan+rosenbaums+essential+films/ -0.055049  0.055049
# 7972                       /lists/more+noirs+from+tspdt/ -0.053799  0.053799
# 7763      /lists/the+21st+centurys+most+acclaimed+films/ -0.053375  0.053375
# 13394  /lists/unescos+memory+of+the+world+national+ci... -0.051918  0.051918
# 7172   /lists/unescos+memory+of+the+world+national+ci... -0.050509  0.050509
# 7152                    /lists/the+criterion+collection/ -0.050437  0.050437
# 10548       /lists/sight+and+sound+2012+-+combined+list/ -0.050379  0.050379
# 7672                  /lists/asian+cinema+a+field+guide/ -0.048444  0.048444
# 7052        /lists/amos+vogels+film+as+a+subversive+art/ -0.044897  0.044897
# 14648    /lists/the+british+film+institute+360+classics/ -0.044867  0.044867
# 7733                       /lists/more+noirs+from+tspdt/ -0.044041  0.044041
# 7765              /lists/the+best+1000+movies+ever+made/ -0.043321  0.043321
